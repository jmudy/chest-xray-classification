# %% [markdown]
# # Importar las librerías

# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.models import load_model
from keras.preprocessing import image

# %% [markdown]
# # Carga del modelo

# %%
modelpath = "../checkpoint/mymodel.hdf5"
model = load_model(filepath=modelpath)
# Out:
# WARNING:tensorflow:From c:\Users\mudar\Documents\repos\chest-xray-classification\.env\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From c:\Users\mudar\Documents\repos\chest-xray-classification\.env\Lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.

# %% [markdown]
# # Predicciones sobre un única imagen

# %%
target_size = (220, 220)

img = image.load_img(
    "../img_tests/pneumonia.jpeg",
    target_size=target_size
    )
plt.imshow(img)

img = image.img_to_array(img)
img = np.expand_dims(img, axis=0)

# %%
result = model.predict(img)
print(result)

if result[0][0] == 1:
    prediction = "Pneumonia"
else:
    prediction = "Normal"

print("El paciente tiene {}".format(prediction))
# Out:
# 1/1 [==============================] - 3s 3s/step
# [[1.]]
# El paciente tiene Pneumonia
